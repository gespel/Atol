# %%
from atol import Atol 

a = Atol()
a.enable_monitor_mode()
print(a.scan_for_aps())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from atol import Atol
#       3 a = Atol()
#       4 a.enable_monitor_mode()
#
# File ~/Projekte/Atol/atol.py:52
#      48         process.wait()
#      51 a = Atol()
# ---> 52 a.enable_monitor_mode()
#      53 print(a.scan_for_aps())
#
# File ~/Projekte/Atol/atol.py:11, in Atol.enable_monitor_mode(self, interface)
#       9 def enable_monitor_mode(self, interface="wlan1"):
#      10     cmd = ["airmon-ng", "start", interface]
# ---> 11     process = subprocess.Popen(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
#      12     process.wait()
#
# ...
